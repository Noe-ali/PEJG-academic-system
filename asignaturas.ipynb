# %% [markdown]
# # Horarios (Modo Administrador)

# %%
import subjects

# %% [markdown]
# Aquí puedes consultar la lista de horarios, modificar las asignaturas o hacer otro tipo de cambios.

# %% [markdown]
# ## Asignaturas

# %%
df = subjects.cargar_archivo('./Programacion.xlsx')
display(df)
# Out:
#        Programas    NRC      Clave               Materia    Secc    Dias  \
# 0     Programa A  10001    Clave 1             Materia 1     OO1      AJ
# 1     Programa A  10001    Clave 1             Materia 1     OO1      LM
# 2     Programa A  10001    Clave 1             Materia 1     OO1       V
# 3     Programa A  10001    Clave 1             Materia 1     OO1       V
# 4     Programa A  10002    Clave 2             Materia 2     OO1       A
# ...          ...    ...        ...                   ...     ...     ...
# 1256  Programa E  10711  Clave 246       Servicio Social     OO1     NaN
# 1257  Programa E  10712  Clave 247  Practica Profesional     OO1     NaN
# 1258  Programa E  10713  Clave 247  Practica Profesional     OO2     NaN
# 1259  Programa E  10714  Clave 246       Servicio Social     OO2     NaN
# 1260      123123  77777     123123                123123  123123  123123
#
#            Hora      Profesor           Salon Listas_cruzadas
# ...

# %% [markdown]
# ### Búsqueda

# %%
clave_asignatura = input("Ingrese el NRC o la Clave de la asignatura a buscar:")
asignatura_encontrada = subjects.buscar_asignatura(df, clave_asignatura)
display(asignatura_encontrada)
# Out:
# Ingrese el NRC o la Clave de la asignatura a buscar: 123123
#      Programas    NRC   Clave Materia    Secc    Dias    Hora Profesor  \
# 1260    123123  77777  123123  123123  123123  123123  123123   123123
#
#        Salon Listas_cruzadas
# 1260  123123             123
